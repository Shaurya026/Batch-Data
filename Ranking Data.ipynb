# %%
import PyPDF3 as X
import pandas as pd

# %% [markdown]
# # Calculating for Sem - 6 for all EP students :

# %%
object = open('E21_BTECH_VI_1253.pdf','rb')
reader = X.PdfFileReader(object)
pages = reader.numPages

# %%
head = dict()
for i in range(pages):
    page1 = reader.getPage(i)
    str = page1.extractText()
    str1 = " " 
    word = ""
    flag = False
    for i in str:
        tmp = i 
        if word == "Papers Failed" and flag == False :
            str1 = " "
            flag = True
        if word == "Digitally":
            break
        if i == '\n':
            word = ""
        if i == '\n' and tmp == i:
            if str1[-1] == '\n':
                continue
            str1 += i
            continue
        str1 += i
        word += str1[-1]
    #print(str1)
    str1 = list(str1.split('\n'))
    #print(str1)
    ctr = 0
    for i in str1:
        if i.startswith("2K18/EP/"):
            #print(str)
            head[str1[ctr-2]] = head.get(str1[ctr-2],list()) #append(str1[ctr-1]) for 1st SEM
            head[str1[ctr-2]].append(i)                      #append Roll Number
            if str1[ctr+8].startswith('Page'):
                head[str1[ctr-2]].append(str1[ctr+7])
                continue
            if float(str1[ctr+8]) > 10: # case arises dues to inclusion of MOOCS and adding 7th course
                head[str1[ctr-2]].append(str1[ctr+9]) #head["Sem-1"].append(str1[ctr+8])
            else:
                head[str1[ctr-2]].append(str1[ctr+8])      
        ctr += 1

# %%
len(head)
# Out:
# 88

# %% [markdown]
# # Calculating for Sem - 5 for all EP students :
# ## Common Students (with 22 credits)

# %%
object = open('O20_BTECH_1184.pdf','rb')
reader = X.PdfFileReader(object)
pages = reader.numPages

# %%
#head = dict()
for i in range(pages):
    page1 = reader.getPage(i)
    str = page1.extractText()
    str1 = " " 
    word = ""
    flag = False
    for i in str:
        tmp = i 
        if word == "Papers Failed" and flag == False :
            str1 = " "
            flag = True
        if word == "Digitally":
            break
        if i == '\n':
            word = ""
        if i == '\n' and tmp == i:
            if str1[-1] == '\n':
                continue
            str1 += i
            continue
        str1 += i
        word += str1[-1]
    #print(str1)
    str1 = list(str1.split('\n'))
    #print(str1)
    ctr = 0
    for i in str1:
        if i.startswith("2K18/EP/"):
            #print(str)
            head[str1[ctr-2]] = head.get(str1[ctr-2],list()) #append(str1[ctr-1]) for 1st SEM
            #head[str1[ctr-2]].append(i)                      #append Roll Number
            if str1[ctr+8].startswith('Page'):
                head[str1[ctr-2]].append(str1[ctr+7])
                continue
            if float(str1[ctr+8]) > 10: # case arises dues to inclusion of MOOCS and adding 7th course
                head[str1[ctr-2]].append(str1[ctr+9]) #head["Sem-1"].append(str1[ctr+8])
            else:
                head[str1[ctr-2]].append(str1[ctr+8])      
        ctr += 1

# %%
len(head)
# Out:
# 88

# %% [markdown]
# ## Other Track Students (with 18 credits)

# %%
object = open('O20_BTECH_V_1193.pdf','rb')
reader = X.PdfFileReader(object)
pages = reader.numPages

# taking name of students we need to take only 18 credits for
exceptions = []

# %%
#head = dict()
for i in range(pages):
    page1 = reader.getPage(i)
    str = page1.extractText()
    str1 = " " 
    word = ""
    flag = False
    for i in str:
        tmp = i 
        if word == "Papers Failed" and flag == False :
            str1 = " "
            flag = True
        if word == "Digitally":
            break
        if i == '\n':
            word = ""
        if i == '\n' and tmp == i:
            if str1[-1] == '\n':
                continue
            str1 += i
            continue
        str1 += i
        word += str1[-1]
    #print(str1)
    str1 = list(str1.split('\n'))
    #print(str1)
    ctr = 0
    for i in str1:
        if i.startswith("2K18/EP/"):
            #print(str1)
            exceptions.append(str1[ctr-2])
            head[str1[ctr-2]] = head.get(str1[ctr-2],list()) #append(str1[ctr-1]) for 1st SEM
            # head[str1[ctr-2]].append(i)                      #append Roll Number
            if str1[ctr+7].startswith('Sr.No'):
                head[str1[ctr-2]].append(str1[ctr+6])
                continue
            if float(str1[ctr+7]) > 10: # case arises dues to inclusion of MOOCS and adding 7th course
                head[str1[ctr-2]].append(str1[ctr+8]) #head["Sem-1"].append(str1[ctr+8])
            else:
                head[str1[ctr-2]].append(str1[ctr+7])      
        ctr += 1

# %%
exceptions
# Out:
# ['SAVINAY KUMAR',
#  'GAURAV MANGAL',
#  'VIKRANT KUMAR PATEL',
#  'ROHIT CHAURASIYA',
#  'AMAN TYAGI',
#  'SHOBHIT RANJAN',
#  'AYUSH KOVIND']

# %% [markdown]
# # Calculating for Sem - 4 for all EP students :

# %%
object = open('E20_BTECH_IV_1106.pdf','rb')
reader = X.PdfFileReader(object)
pages = reader.numPages

# %%
#head = dict()
for i in range(pages):
    page1 = reader.getPage(i)
    str = page1.extractText()
    str1 = " " 
    word = ""
    flag = False
    for i in str:
        tmp = i 
        if word == "Papers Failed" and flag == False :
            str1 = " "
            flag = True
        if word == "Digitally":
            break
        if i == '\n':
            word = ""
        if i == '\n' and tmp == i:
            if str1[-1] == '\n':
                continue
            str1 += i
            continue
        str1 += i
        word += str1[-1]
    #print(str1)
    str1 = list(str1.split('\n'))
    #print(str1)
    ctr = 0
    for i in str1:
        if i.startswith("2K18/EP/"):
#             if str1[ctr-2] == 'ASHISH RANJAN': # lateral entry
#                 head['ASHEESH RANJAN'] = head.get('ASHEESH RANJAN',list())
#                 head['ASHEESH RANJAN'].append(i)
#                 head['ASHEESH RANJAN'].append(str1[ctr+8])
#                 ctr += 1
#                 continue
            head[str1[ctr-2]] = head.get(str1[ctr-2],list()) #append(str1[ctr-1]) for 1st SEM
            #head[str1[ctr-2]].append(i)          #head["Roll No."].append(i)
            if str1[ctr-2] == "ASHWAJIT SINGH":
                    head[str1[ctr-2]].append(str1[ctr+6])
                    ctr += 1
                    continue
            head[str1[ctr-2]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
        ctr += 1

# %%
# # for k,v in head.items():
# #     print(k,":",end="")
# #     print(len(v))
# # print(head)
# print(len(head))

# %%
print('ANOMALIES TO BE SORTED MANUALLY SINCE THEIR RESULTS WERE DECLARED LATER:')
for i,j in head.items():
    if len(j) == 3:
        print(i)
# Out:
# ANOMALIES TO BE SORTED MANUALLY SINCE THEIR RESULTS WERE DECLARED LATER:
# PIYUSH BHATIA
# SHAURYA PARASHAR
# SARVAGYA KUMAR

# %%
# found in RESULT FILE 1119
head['SHAURYA PARASHAR'].append('7.27')
head['SARVAGYA KUMAR'].append('7.18')
head['PIYUSH BHATIA'].append('5.27')

# %%
head
# Out:
# {'PIYUSH BHATIA': ['2K18/EP/056', '8.43', '8.86', '5.27'],
#  'AYUSH KISHORE': ['2K18/EP/019', '8.96', '8.73', '6.09'],
#  'VINAY YADAV': ['2K18/EP/090', '8.65', '8.55', '5.64'],
#  'ABHISHEK GARG': ['2K18/EP/002', '9.30', '9.05', '7.18'],
#  'PRIYANSH BHATNAGAR': ['2K18/EP/058', '9.65', '9.55', '9.45'],
#  'SHAURYA PARASHAR': ['2K18/EP/079', '8.78', '9.09', '7.27'],
#  'VIKRANT KUMAR PATEL': ['2K18/EP/089', '8.65', '8.67', '9.18'],
#  'AKSHAT TIWARI': ['2K18/EP/008', '9.48', '9.32', '7.64'],
#  'JOSH VISHNOI': ['2K18/EP/035', '9.13', '8.95', '8.82'],
#  'NIPUL AGARWAL': ['2K18/EP/054', '9.48', '9.00', '8.55'],
#  'RAUNAQ SINGH': ['2K18/EP/061', '9.17', '8.82', '8.91'],
#  'SAVINAY KUMAR': ['2K18/EP/077', '9.13', '9.17', '9.27'],
#  'SOHUM GUPTA': ['2K18/EP/082', '8.78', '8.86', '7.73'],
#  'RUDRA PRATAP SINGH': ['2K18/EP/068', '3.58', '5.45', '5.00'],
#  'NIKHIL DHUPER': ['2K18/EP/051', '8.83', '9.14', '7.36'],
#  'AMAN KALA': ['2K18/EP/009', '8.78', '8.64', '7.00'],
#  'AMAN TYAGI': ['2K18/EP/010', '9.83', '9.44', '9.64'],
#  'DEEPANSHU SINGH': ['2K18/EP/023', '8.61', '8.82', '7.45'],
#  'GIRISH ASHTA': ['2K18/EP/028', '9.48', '9.55', '6.27'],
#  'JAI PRAKASH': ['2K18/EP/033', '8.96', '9.50', '8.18'],
#  'KARTIK ROHTELA': ['2K18/EP/037', '8.65', '8.41', '6.73'],
#  'KARTIKEY KOLI': ['2K18/EP/038', '8.30', '8.36', '6.36'],
#  'KSHITIZ SHARMA': ['2K18/EP/041', '8.65', '9.00', '9.18'],
#  'MOHIT KUMAR': ['2K18/EP/048', '8.83', '8.95', '8.00'],
#  'MOHIT YADAV': ['2K18/EP/050', '8.83', '8.55', '8.00'],
#  'NILESH PANDEY': ['2K18/EP/053', '9.00', '9.36', '8.45'],
#  'SANCHIT KUMAR': ['2K18/EP/072', '8.61', '7.68', '6.64'],
#  'SANYAM PANDEY': ['2K18/EP/073', '9.65', '8.68', '8.18'],
#  'SATISH KUMAR': ['2K18/EP/075', '8.78', '7.79', '6.18'],
#  'SHIKHAR DASH': ['2K18/EP/080', '9.35', '9.32', '9.45'],
#  'SHOBHIT RANJAN': ['2K18/EP/081', '9.17', '9.22', '9.45'],
#  'T.S.SACHIN VENKATESH': ['2K18/EP/084', '9.00', '9.18', '6.45'],
#  'LEKHAK KUMAR': ['2K18/EP/043', '8.65', '8.41', '6.18'],
#  'AMIT SETH': ['2K18/EP/012', '8.96', '9.07', '2.73'],
#  'EBANI GUPTA': ['2K18/EP/025', '9.48', '9.23', '9.09'],
#  'KANISHK': ['2K18/EP/036', '9.65', '8.82', '8.00'],
#  'MANASVI SINGWAL': ['2K18/EP/045', '8.65', '9.05', '6.27'],
#  'MAYANK SINGH': ['2K18/EP/046', '9.13', '9.18', '6.27'],
#  'PUSHKAR SHARMA': ['2K18/EP/059', '8.83', '8.73', '8.18'],
#  'ROHIT CHAURASIYA': ['2K18/EP/067', '9.48', '9.22', '8.18'],
#  'RUSHIL KUMAR': ['2K18/EP/069', '9.65', '9.32', '9.00'],
#  'SAHAJ RASTOGI': ['2K18/EP/070', '9.65', '9.50', '9.09'],
#  'SARVAGYA KUMAR': ['2K18/EP/074', '9.30', '9.18', '7.18'],
#  'YASH MUDGAL': ['2K18/EP/093', '9.48', '9.18', '9.27'],
#  'RITWIK POKHRIYAL': ['2K18/EP/065', '7.96', '4.68', '5.27'],
#  'AYUSH KOVIND': ['2K18/EP/020', '8.65', '9.07', '7.64'],
#  'AKHIL GUPTA': ['2K18/EP/006', '9.65', '9.64', '9.18'],
#  'AKSHANSH': ['2K18/EP/007', '7.96', '8.36', '5.64'],
#  'ANANT GUPTA': ['2K18/EP/013', '9.13', '7.86', '7.45'],
#  'ANUBHAV RAI': ['2K18/EP/014', '8.83', '9.14', '7.36'],
#  'ARPIT YADAV': ['2K18/EP/016', '8.30', '7.86', '6.18'],
#  'ASHWAJIT SINGH': ['2K18/EP/018', '8.96', '8.73', '5.57'],
#  'DIVYAM NIGAM': ['2K18/EP/024', '8.48', '5.82', '5.73'],
#  'KHUSHBOO': ['2K18/EP/039', '9.48', '9.00', '8.55'],
#  'KUNAL THAKUR': ['2K18/EP/042', '9.00', '9.09', '6.55'],
#  'MALAY GARG': ['2K18/EP/044', '8.65', '8.36', '7.36'],
#  'PRANAVA PRAKASH J': ['2K18/EP/057', '8.83', '8.64', '8.27'],
#  'RITIK TIWARI': ['2K18/EP/064', '9.00', '8.18', '8.27'],
#  'ROHAN JOSHI': ['2K18/EP/066', '9.65', '9.14', '7.82'],
#  'SAI SPANDANA THALLAM': ['2K18/EP/071', '9.30', '9.00', '9.82'],
#  'VISHNU DEV SINGH': ['2K18/EP/092', '9.00', '9.14', '6.36'],
#  'ABHISHEK GAUTAM': ['2K18/EP/003', '9.17', '8.18', '7.55'],
#  'ASHISH RANJAN': ['2K18/EP/017', '8.96', '8.59', '7.45'],
#  'AYUSH RAJ': ['2K18/EP/021', '9.35', '9.32', '7.91'],
#  'GAURAV MANGAL': ['2K18/EP/027', '9.35', '9.39', '9.64'],
#  'GAURAV KHULWAY': ['2K18/EP/026', '9.52', '9.13', '7.82'],
#  'RAMENDRA VERMA': ['2K18/EP/060', '9.30', '8.45', '7.00'],
#  'SATYAM GUPTA': ['2K18/EP/076', '9.83', '9.29', '8.45'],
#  'VIKAS VERMA': ['2K18/EP/088', '9.35', '9.13', '6.91'],
#  'GOODLUCK': ['2K18/EP/029', '8.65', '8.45', '6.09'],
#  'YASH YADAV': ['2K18/EP/094', '9.35', '8.82', '7.27'],
#  'VEDANT CHOUKSEY': ['2K18/EP/087', '9.30', '9.00', '7.00'],
#  'ISHU': ['2K18/EP/032', '9.35', '8.32', '7.09'],
#  'SWAPNIL VERMA': ['2K18/EP/083', '8.83', '8.36', '5.82'],
#  'MOHIT SHARMA': ['2K18/EP/049', '9.17', '9.18', '6.64'],
#  'RAVI': ['2K18/EP/062', '9.35', '8.73', '7.45'],
#  'VIPUL PHULIA': ['2K18/EP/091', '8.83', '8.64', '8.36'],
#  'TARUN ARORA': ['2K18/EP/085', '9.52', '9.27', '9.27'],
#  'SHAURYA GUPTA': ['2K18/EP/078', '9.83', '9.55', '9.82'],
#  'VARUN MATHUR': ['2K18/EP/086', '9.65', '9.18', '9.64'],
#  'AGASTYA SETHI': ['2K18/EP/005', '9.17', '9.05', '8.55'],
#  'BHUVAN VED': ['2K18/EP/022', '9.17', '8.95', '7.09'],
#  'HARISH KUMAR': ['2K18/EP/030', '9.30', '9.05', '6.00'],
#  'KRITIN SYAL': ['2K18/EP/040', '9.30', '8.95', '7.45'],
#  'MEETALI CHOUDHARY': ['2K18/EP/047', '9.70', '9.23', '8.45'],
#  'HARSH PANCHAL': ['2K18/EP/031', '9.48', '8.68', '7.27'],
#  'PANKAJ KUMAR': ['2K18/EP/055', '8.61', '8.55', '6.73'],
#  'AMAR KUMAR': ['2K18/EP/011', '8.78', '8.68', '5.82']}

# %% [markdown]
# # Calculating for Sem - 3 for all EP students :
# Since Roll numbers start with 2K18/EP for batch which is designated in 3rd Sem so we start in descending order to calculate

# %%
object = open('O19_BTECH_3_1014.pdf','rb')
reader = X.PdfFileReader(object)
pages = reader.numPages

# %%
#head = dict()
for i in range(pages):
    page1 = reader.getPage(i)
    str = page1.extractText()
    str1 = " " 
    word = ""
    flag = False
    for i in str:
        tmp = i 
        if word == "Papers Failed" and flag == False :
            str1 = " "
            flag = True
        if word == "Digitally":
            break
        if i == '\n':
            word = ""
        if i == '\n' and tmp == i:
            if str1[-1] == '\n':
                continue
            str1 += i
            continue
        str1 += i
        word += str1[-1]
    #print(str1)
    str1 = list(str1.split('\n'))
    #print(str1)
    ctr = 0
    for i in str1:
        if i.startswith("2K18/EP/"):
            head[str1[ctr-2]] = head.get(str1[ctr-2],list()) #append(str1[ctr-1]) for 1st SEM
            # if result was not present in SEM-4
            if len(head[str1[ctr-2]]) == 0:
                #head[str1[ctr-2]].append(i)          #head["Roll No."].append(i)
                head[str1[ctr-2]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
            if str1[ctr-2] == "ASHWAJIT SINGH":
                    head[str1[ctr-2]].append(str1[ctr+7])
                    ctr += 1
                    continue
            head[str1[ctr-2]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
            
        ctr += 1
# for k,v in head.items():
#     print(k,":",end="")
#     print(len(v))

# %%
print('ANOMALIES TO BE SORTED MANUALLY SINCE THEIR RESULTS WERE DECLARED LATER:')
for i,j in head.items():
    if len(j) <= 4:
        print(i)
# Out:
# ANOMALIES TO BE SORTED MANUALLY SINCE THEIR RESULTS WERE DECLARED LATER:
# ASHISH RANJAN
# ASHEESH RANJAN
# ADITYA AMBARIK

# %%
head['ASHISH RANJAN'].append(head['ASHEESH RANJAN'][0])

# %%
head['ASHEESH RANJAN'] = head['ASHISH RANJAN']
del(head['ASHISH RANJAN'])

# %%
len(head)
# Out:
# 89

# %% [markdown]
# # Calculating for Sem - 2 :

# %%
object = open('E19_BTECH_B_2_929.pdf','rb')
reader = X.PdfFileReader(object)
pages = reader.numPages

# %%
for i in range(pages):
    page1 = reader.getPage(i)
    str = page1.extractText()
    str1 = " " 
    word = ""
    flag = False
    for i in str:
        tmp = i 
        if word == "Papers Failed" and flag == False :
            str1 = " "
            flag = True
        if word == "Digitally":
            break
        if i == '\n':
            word = ""
        if i == '\n' and tmp == i:
            if str1[-1] == '\n':
                continue
            str1 += i
            continue
        str1 += i
        word += str1[-1]
    #print(str1)
    str1 = list(str1.split('\n'))
    #print(str1)
    ctr = 0
    for i in str1:
        if i.startswith("2K18/B8") and (str1[ctr-2] in head.keys()) :
            head[str1[ctr-2]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
        ctr += 1

# %%
# works fine till here !!

# %%
head
# Out:
# {'PIYUSH BHATIA': ['2K18/EP/056',
#   '8.43',
#   '8.86',
#   '5.27',
#   '2.73',
#   '4.00',
#   '4.70'],
#  'AYUSH KISHORE': ['2K18/EP/019',
#   '8.96',
#   '8.73',
#   '6.09',
#   '3.45',
#   '2.50',
#   '4.90'],
#  'VINAY YADAV': ['2K18/EP/090',
#   '8.65',
#   '8.55',
#   '5.64',
#   '4.36',
#   '2.10',
#   '5.30'],
#  'ABHISHEK GARG': ['2K18/EP/002',
#   '9.30',
#   '9.05',
#   '7.18',
#   '5.55',
#   '5.63',
#   '6.10'],
#  'PRIYANSH BHATNAGAR': ['2K18/EP/058',
#   '9.65',
#   '9.55',
#   '9.45',
#   '9.82',
#   '8.60',
#   '9.20'],
#  'SHAURYA PARASHAR': ['2K18/EP/079',
#   '8.78',
#   '9.09',
#   '7.27',
#   '7.73',
#   '7.40',
#   '7.20'],
#  'VIKRANT KUMAR PATEL': ['2K18/EP/089',
#   '8.65',
#   '8.67',
#   '9.18',
#   '8.36',
#   '8.50',
#   '6.50'],
#  'AKSHAT TIWARI': ['2K18/EP/008', '9.48', '9.32', '7.64', '7.82', 7.8, '6.70'],
#  'JOSH VISHNOI': ['2K18/EP/035',
#   '9.13',
#   '8.95',
#   '8.82',
#   '8.45',
#   '6.90',
#   '7.80'],
#  'NIPUL AGARWAL': ['2K18/EP/054',
#   '9.48',
#   '9.00',
#   '8.55',
#   '8.64',
#   '8.05',
#   '8.30'],
#  'RAUNAQ SINGH': ['2K18/EP/061',
#   '9.17',
#   '8.82',
#   '8.91',
#   '9.18',
#   '7.53',
#   '8.10'],
#  'SAVINAY KUMAR': ['2K18/EP/077',
#   '9.13',
#   '9.17',
#   '9.27',
#   '8.45',
#   '8.10',
#   '7.60'],
#  'SOHUM GUPTA': ['2K18/EP/082',
#   '8.78',
#   '8.86',
#   '7.73',
#   '8.09',
#   '6.00',
#   '7.10'],
#  'RUDRA PRATAP SINGH': ['2K18/EP/068',
#   '3.58',
#   '5.45',
#   '5.00',
#   '4.27',
#   '4.50',
#   '4.90'],
#  'NIKHIL DHUPER': ['2K18/EP/051',
#   '8.83',
#   '9.14',
#   '7.36',
#   '7.55',
#   '6.30',
#   '7.50'],
#  'AMAN KALA': ['2K18/EP/009', '8.78', '8.64', '7.00', '6.82', '5.95', '6.80'],
#  'AMAN TYAGI': ['2K18/EP/010',
#   '9.83',
#   '9.44',
#   '9.64',
#   '10.00',
#   '9.00',
#   '9.30'],
#  'DEEPANSHU SINGH': ['2K18/EP/023',
#   '8.61',
#   '8.82',
#   '7.45',
#   '5.64',
#   '5.80',
#   '7.00'],
#  'GIRISH ASHTA': ['2K18/EP/028',
#   '9.48',
#   '9.55',
#   '6.27',
#   '4.36',
#   '3.90',
#   '5.00'],
#  'JAI PRAKASH': ['2K18/EP/033', '8.96', '9.50', '8.18', '7.73', '7.20'],
#  'KARTIK ROHTELA': ['2K18/EP/037',
#   '8.65',
#   '8.41',
#   '6.73',
#   '4.73',
#   '6.10',
#   '6.60'],
#  'KARTIKEY KOLI': ['2K18/EP/038',
#   '8.30',
#   '8.36',
#   '6.36',
#   '3.64',
#   '5.50',
#   '3.30'],
#  'KSHITIZ SHARMA': ['2K18/EP/041',
#   '8.65',
#   '9.00',
#   '9.18',
#   '8.73',
#   '8.70',
#   '8.20'],
#  'MOHIT KUMAR': ['2K18/EP/048',
#   '8.83',
#   '8.95',
#   '8.00',
#   '7.09',
#   '7.70',
#   '7.10'],
#  'MOHIT YADAV': ['2K18/EP/050',
#   '8.83',
#   '8.55',
#   '8.00',
#   '6.82',
#   '7.00',
#   '6.90'],
#  'NILESH PANDEY': ['2K18/EP/053',
#   '9.00',
#   '9.36',
#   '8.45',
#   '8.64',
#   '9.00',
#   '7.60'],
#  'SANCHIT KUMAR': ['2K18/EP/072',
#   '8.61',
#   '7.68',
#   '6.64',
#   '5.18',
#   '4.00',
#   '4.30'],
#  'SANYAM PANDEY': ['2K18/EP/073',
#   '9.65',
#   '8.68',
#   '8.18',
#   '7.91',
#   '6.79',
#   '7.30'],
#  'SATISH KUMAR': ['2K18/EP/075',
#   '8.78',
#   '7.79',
#   '6.18',
#   '1.82',
#   '4.89',
#   '4.80'],
#  'SHIKHAR DASH': ['2K18/EP/080',
#   '9.35',
#   '9.32',
#   '9.45',
#   '9.55',
#   '9.50',
#   '9.20'],
#  'SHOBHIT RANJAN': ['2K18/EP/081',
#   '9.17',
#   '9.22',
#   '9.45',
#   '9.18',
#   '9.00',
#   '7.40'],
#  'T.S.SACHIN VENKATESH': ['2K18/EP/084',
#   '9.00',
#   '9.18',
#   '6.45',
#   '4.73',
#   '4.10',
#   '5.80'],
#  'LEKHAK KUMAR': ['2K18/EP/043',
#   '8.65',
#   '8.41',
#   '6.18',
#   '5.64',
#   '4.80',
#   '5.10'],
#  'AMIT SETH': ['2K18/EP/012', '8.96', '9.07', '2.73', '0.82', '1.60', '3.80'],
#  'EBANI GUPTA': ['2K18/EP/025',
#   '9.48',
#   '9.23',
#   '9.09',
#   '8.18',
#   '7.30',
#   '7.90'],
#  'KANISHK': ['2K18/EP/036', '9.65', '8.82', '8.00', '8.09', '5.60', '5.50'],
#  'MANASVI SINGWAL': ['2K18/EP/045',
#   '8.65',
#   '9.05',
#   '6.27',
#   '4.82',
#   7.0,
#   '3.90'],
#  'MAYANK SINGH': ['2K18/EP/046',
#   '9.13',
#   '9.18',
#   '6.27',
#   '4.82',
#   '4.10',
#   '8.50'],
#  'PUSHKAR SHARMA': ['2K18/EP/059',
#   '8.83',
#   '8.73',
#   '8.18',
#   '8.00',
#   '7.50',
#   '7.20'],
#  'ROHIT CHAURASIYA': ['2K18/EP/067',
#   '9.48',
#   '9.22',
#   '8.18',
#   '8.91',
#   '8.40',
#   '8.10'],
#  'RUSHIL KUMAR': ['2K18/EP/069',
#   '9.65',
#   '9.32',
#   '9.00',
#   '8.09',
#   '7.20',
#   '6.60'],
#  'SAHAJ RASTOGI': ['2K18/EP/070',
#   '9.65',
#   '9.50',
#   '9.09',
#   '8.09',
#   '6.60',
#   '7.50'],
#  'SARVAGYA KUMAR': ['2K18/EP/074',
#   '9.30',
#   '9.18',
#   '7.18',
#   '6.45',
#   '6.80',
#   '4.90'],
#  'YASH MUDGAL': ['2K18/EP/093',
#   '9.48',
#   '9.18',
#   '9.27',
#   '9.27',
#   '7.50',
#   '8.70'],
#  'RITWIK POKHRIYAL': ['2K18/EP/065',
#   '7.96',
#   '4.68',
#   '5.27',
#   '4.64',
#   '5.90',
#   '6.30'],
#  'AYUSH KOVIND': ['2K18/EP/020',
#   '8.65',
#   '9.07',
#   '7.64',
#   '6.55',
#   '6.10',
#   '5.60'],
#  'AKHIL GUPTA': ['2K18/EP/006',
#   '9.65',
#   '9.64',
#   '9.18',
#   '9.09',
#   '9.40',
#   '7.50'],
#  'AKSHANSH': ['2K18/EP/007', '7.96', '8.36', '5.64', '2.82', '1.63', '1.10'],
#  'ANANT GUPTA': ['2K18/EP/013',
#   '9.13',
#   '7.86',
#   '7.45',
#   '6.55',
#   '6.00',
#   '6.70'],
#  'ANUBHAV RAI': ['2K18/EP/014',
#   '8.83',
#   '9.14',
#   '7.36',
#   '5.27',
#   '4.50',
#   '7.00'],
#  'ARPIT YADAV': ['2K18/EP/016',
#   '8.30',
#   '7.86',
#   '6.18',
#   '3.64',
#   '5.20',
#   '6.50'],
#  'ASHWAJIT SINGH': ['2K18/EP/018',
#   '8.96',
#   '8.73',
#   '5.57',
#   '3.11',
#   '0.70',
#   '1.40'],
#  'DIVYAM NIGAM': ['2K18/EP/024',
#   '8.48',
#   '5.82',
#   '5.73',
#   '3.18',
#   '1.90',
#   '4.20'],
#  'KHUSHBOO': ['2K18/EP/039', '9.48', '9.00', '8.55', '8.18', '6.50', '7.10'],
#  'KUNAL THAKUR': ['2K18/EP/042',
#   '9.00',
#   '9.09',
#   '6.55',
#   '6.82',
#   '6.05',
#   '5.40'],
#  'MALAY GARG': ['2K18/EP/044', '8.65', '8.36', '7.36', '7.82', '5.30', '3.90'],
#  'PRANAVA PRAKASH J': ['2K18/EP/057',
#   '8.83',
#   '8.64',
#   '8.27',
#   '7.73',
#   '7.70',
#   '7.50'],
#  'RITIK TIWARI': ['2K18/EP/064',
#   '9.00',
#   '8.18',
#   '8.27',
#   '8.09',
#   '6.90',
#   '7.70'],
#  'ROHAN JOSHI': ['2K18/EP/066',
#   '9.65',
#   '9.14',
#   '7.82',
#   '8.00',
#   '8.60',
#   '6.80'],
#  'SAI SPANDANA THALLAM': ['2K18/EP/071',
#   '9.30',
#   '9.00',
#   '9.82',
#   '9.64',
#   '8.00',
#   '8.70'],
#  'VISHNU DEV SINGH': ['2K18/EP/092',
#   '9.00',
#   '9.14',
#   '6.36',
#   '4.64',
#   '4.60',
#   '3.80'],
#  'ABHISHEK GAUTAM': ['2K18/EP/003',
#   '9.17',
#   '8.18',
#   '7.55',
#   '7.00',
#   '6.60',
#   '6.90'],
#  'AYUSH RAJ': ['2K18/EP/021', '9.35', '9.32', '7.91', '8.45', '6.42', '7.10'],
#  'GAURAV MANGAL': ['2K18/EP/027',
#   '9.35',
#   '9.39',
#   '9.64',
#   '9.82',
#   '6.90',
#   '7.10'],
#  'GAURAV KHULWAY': ['2K18/EP/026',
#   '9.52',
#   '9.13',
#   '7.82',
#   '6.18',
#   '4.53',
#   '6.40'],
#  'RAMENDRA VERMA': ['2K18/EP/060',
#   '9.30',
#   '8.45',
#   '7.00',
#   '6.45',
#   '3.40',
#   '4.00'],
#  'SATYAM GUPTA': ['2K18/EP/076',
#   '9.83',
#   '9.29',
#   '8.45',
#   '8.27',
#   '7.10',
#   '8.00'],
#  'VIKAS VERMA': ['2K18/EP/088',
#   '9.35',
#   '9.13',
#   '6.91',
#   '6.55',
#   '5.32',
#   '5.80'],
#  'GOODLUCK': ['2K18/EP/029', '8.65', '8.45', '6.09', '4.55', '3.20', '4.10'],
#  'YASH YADAV': ['2K18/EP/094', '9.35', '8.82', '7.27', '6.55', '5.20', '4.70'],
#  'VEDANT CHOUKSEY': ['2K18/EP/087',
#   '9.30',
#   '9.00',
#   '7.00',
#   '6.91',
#   '5.60',
#   '6.40'],
#  'ISHU': ['2K18/EP/032', '9.35', '8.32', '7.09', '5.64', '6.79'],
#  'SWAPNIL VERMA': ['2K18/EP/083',
#   '8.83',
#   '8.36',
#   '5.82',
#   '3.36',
#   '5.40',
#   '5.80'],
#  'MOHIT SHARMA': ['2K18/EP/049',
#   '9.17',
#   '9.18',
#   '6.64',
#   '6.91',
#   '5.50',
#   '6.70'],
#  'RAVI': ['2K18/EP/062', '9.35', '8.73', '7.45', '7.09', '7.80', '6.60'],
#  'VIPUL PHULIA': ['2K18/EP/091',
#   '8.83',
#   '8.64',
#   '8.36',
#   '7.82',
#   '7.10',
#   '6.90'],
#  'TARUN ARORA': ['2K18/EP/085',
#   '9.52',
#   '9.27',
#   '9.27',
#   '9.73',
#   '9.00',
#   '8.80'],
#  'SHAURYA GUPTA': ['2K18/EP/078',
#   '9.83',
#   '9.55',
#   '9.82',
#   '9.64',
#   '8.10',
#   '8.80'],
#  'VARUN MATHUR': ['2K18/EP/086',
#   '9.65',
#   '9.18',
#   '9.64',
#   '9.18',
#   '8.60',
#   '8.50'],
#  'AGASTYA SETHI': ['2K18/EP/005',
#   '9.17',
#   '9.05',
#   '8.55',
#   '7.82',
#   '8.05',
#   '7.70'],
#  'BHUVAN VED': ['2K18/EP/022', '9.17', '8.95', '7.09', '6.09', '6.58', '7.20'],
#  'HARISH KUMAR': ['2K18/EP/030',
#   '9.30',
#   '9.05',
#   '6.00',
#   '4.09',
#   '4.42',
#   '6.20'],
#  'KRITIN SYAL': ['2K18/EP/040',
#   '9.30',
#   '8.95',
#   '7.45',
#   '6.64',
#   '5.42',
#   '5.00'],
#  'MEETALI CHOUDHARY': ['2K18/EP/047',
#   '9.70',
#   '9.23',
#   '8.45',
#   '7.18',
#   '7.10',
#   '7.00'],
#  'HARSH PANCHAL': ['2K18/EP/031',
#   '9.48',
#   '8.68',
#   '7.27',
#   '5.91',
#   '4.40',
#   '7.10'],
#  'PANKAJ KUMAR': ['2K18/EP/055',
#   '8.61',
#   '8.55',
#   '6.73',
#   '5.18',
#   '5.40',
#   '7.50'],
#  'AMAR KUMAR': ['2K18/EP/011', '8.78', '8.68', '5.82', '2.91', '1.20', '4.10'],
#  'ASHEESH RANJAN': ['2K18/EP/017',
#   '8.96',
#   '8.59',
#   '7.45',
#   '7.36',
#   '4.30',
#   '5.90'],
#  'ADITYA AMBARIK': ['0.00', '0.00']}

# %%
object = open('E19_BTECH_A_2_929.pdf','rb')
reader = X.PdfFileReader(object)
pages = reader.numPages

# %%
for i in range(pages):
    page1 = reader.getPage(i)
    str = page1.extractText()
    str1 = " " 
    word = ""
    flag = False
    for i in str:
        tmp = i 
        if word == "Papers Failed" and flag == False :
            str1 = " "
            flag = True
        if word == "Digitally":
            break
        if i == '\n':
            word = ""
        if i == '\n' and tmp == i:
            if str1[-1] == '\n':
                continue
            str1 += i
            continue
        str1 += i
        word += str1[-1]
    #print(str1)
    str1 = list(str1.split('\n'))
    #print(str1)
    ctr = 0
    for i in str1:
        if i.startswith("2K18/A8/") and (str1[ctr-2] in head.keys()) and (len(head[str1[ctr-2]]) != 6) :
            head[str1[ctr-2]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
        ctr += 1
    ctr = 0
    for i in str1:
        if i.startswith("2K18/") and (str1[ctr-2] in head.keys()) and (len(head[str1[ctr-2]]) == 5):
            head[str1[ctr-2]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
        ctr += 1

# %%
object = open('E19_BTECH_B_2_929.pdf','rb')
reader = X.PdfFileReader(object)
pages = reader.numPages
for i in range(pages):
    page1 = reader.getPage(i)
    str = page1.extractText()
    str1 = " " 
    word = ""
    flag = False
    for i in str:
        tmp = i 
        if word == "Papers Failed" and flag == False :
            str1 = " "
            flag = True
        if word == "Digitally":
            break
        if i == '\n':
            word = ""
        if i == '\n' and tmp == i:
            if str1[-1] == '\n':
                continue
            str1 += i
            continue
        str1 += i
        word += str1[-1]
    #print(str1)
    str1 = list(str1.split('\n'))
    #print(str1)
    ctr = 0
    for i in str1:
        if i.startswith("2K18/") and (str1[ctr-2] in head.keys()) and (len(head[str1[ctr-2]]) == 5):
            head[str1[ctr-2]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
        ctr += 1
head["AKSHAT TIWARI"].append(7.8)
head["MANASVI SINGWAL"].append(7.0)
# for k,v in head.items() :
#     print(k,":",end="")
#     print(len(v))

# %% [markdown]
# # Calculating for Sem - 1 :

# %%
object = open('O18_BTECH.pdf','rb')
reader = X.PdfFileReader(object)
pages = reader.numPages

# %%
for i in range(pages):
    page1 = reader.getPage(i)
    str = page1.extractText()
    str1 = " " 
    word = ""
    flag = False
    for i in str:
        tmp = i 
        if word == "Papers Failed" and flag == False :
            str1 = " "
            flag = True
        if word == "Digitally":
            break
        if i == '\n':
            word = ""
        if i == '\n' and tmp == i:
            if str1[-1] == '\n':
                continue
            str1 += i
            continue
        str1 += i
        word += str1[-1]
    str1 = list(str1.split('\n'))
    #print(str1)
    ctr = 0
    for i in str1:
        if i.startswith("2018/A8") and (str1[ctr-1] in head.keys()) and (len(head[str1[ctr-1]]) == 6 ) :
            head[str1[ctr-1]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
        ctr += 1
    ctr = 0
    for i in str1:
        if i.startswith("2018/B8") and (str1[ctr-1] in head.keys()) and (len(head[str1[ctr-1]]) == 6 ):
            head[str1[ctr-1]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
        ctr += 1
    ctr = 0
    for i in str1:
        if i.startswith("2018/") and (str1[ctr-1] in head.keys()) and (len(head[str1[ctr-1]]) == 6 ):
            head[str1[ctr-1]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
        ctr += 1
#     for i in str1:
#         if i.startswith("2018/A8") and (str1[ctr-1] in head.keys()) :
#             head[str1[ctr-1]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
#         ctr += 1
#         ctr = 0
#     for i in str1:
#         if i.startswith("2018/") and (str1[ctr-1] in head.keys()) and (len(str1[ctr-1]) != 4 ) :
#             head[str1[ctr-1]].append(str1[ctr+8])      #head["Sem-1"].append(str1[ctr+8])
#         ctr += 1

# %%
for i,j in head.items():
    if len(j) != 7:
        print(i)

# %%
head['JAI PRAKASH'].append('7.60') # didn't have sirname in official documents before this sem

# %%
head['ISHU'].append('7.80')

# %% [markdown]
# since aditya ambarik has no data after 4th sem his name is removed!!

# %%
del(head['ADITYA AMBARIK'])

# %%
len(head)
# Out:
# 88

# %%
#print(head)
header = {"Name": [], "Roll No.": [], "Sem-6":[], "Sem-5":[], "Sem-4":[], "Sem-3":[], "Sem-2":[], "Sem-1":[], "Aggregate":[]}
for k,v in head.items():
    header["Name"].append(k)
    header["Roll No."].append(v[0])
    if len(v) < 7 :
        if len(v) == 6:
            header["Sem-6"].append(float(v[1]))
            header["Sem-5"].append(float(v[2]))
            header["Sem-4"].append(float(v[3]))
            header["Sem-3"].append(float(v[4]))
            header["Sem-2"].append(float(v[5]))
            header["Sem-1"].append(6.0)
            continue
    else :
        header["Sem-6"].append(float(v[1]))
        header["Sem-5"].append(float(v[2]))
        header["Sem-4"].append(float(v[3]))
        header["Sem-3"].append(float(v[4]))
        header["Sem-2"].append(float(v[5]))
        if v[4] == "MA101":
            header["Sem-1"].append(6.0)
            continue
        header["Sem-1"].append(float(v[6]))

# %%
len(header['Name'])
header['Name'][1]
# Out:
# 88

# %%
# print(len(header["Name"]))
# print(len(header["Sem-2"]))
# print(len(header["Sem-1"]))
# print(len(header["Roll No."]))
# print(len(header["Sem-3"]))
#print(header)
x = 0
for i in range(88) :
    if header['Name'][i] in exceptions:
        x = (header["Sem-1"][i] * 20 + header["Sem-2"][i] * 20 + header["Sem-3"][i] * 22 + header["Sem-4"][i]*22 + header['Sem-5'][i]*18 + header['Sem-6'][i]*23) / 125
    else:
        x = (header["Sem-1"][i] * 20 + header["Sem-2"][i] * 20 + header["Sem-3"][i] * 22 + header["Sem-4"][i]*22 + header['Sem-5'][i]*22 + header['Sem-6'][i]*23) / 129
    header['Aggregate'].append(x)

# %%
answer = pd.DataFrame(header)
#answer["Aggregate"] = answer.apply( (answer['Sem-1'] * 20 + answer['Sem-2'] * 20 + answer['Sem-3'] * 22) / 62 , axis1) 
answer1 = answer.sort_values(by=['Aggregate'], ascending=False)
print(answer1)
# Out:
#                   Name     Roll No.  Sem-6  Sem-5  Sem-4  Sem-3  Sem-2  Sem-1  \
# 16          AMAN TYAGI  2K18/EP/010   9.83   9.44   9.64  10.00   9.00    9.3
# 29        SHIKHAR DASH  2K18/EP/080   9.35   9.32   9.45   9.55   9.50    9.2
# 4   PRIYANSH BHATNAGAR  2K18/EP/058   9.65   9.55   9.45   9.82   8.60    9.2
# 77       SHAURYA GUPTA  2K18/EP/078   9.83   9.55   9.82   9.64   8.10    8.8
# 76         TARUN ARORA  2K18/EP/085   9.52   9.27   9.27   9.73   9.00    8.8
# ..                 ...          ...    ...    ...    ...    ...    ...    ...
# 52        DIVYAM NIGAM  2K18/EP/024   8.48   5.82   5.73   3.18   1.90    4.2
# 51      ASHWAJIT SINGH  2K18/EP/018   8.96   8.73   5.57   3.11   0.70    1.4
# 47            AKSHANSH  2K18/EP/007   7.96   8.36   5.64   2.82   1.63    1.1
# 13  RUDRA PRATAP SINGH  2K18/EP/068   3.58   5.45   5.00   4.27   4.50    4.9
# 33           AMIT SETH  2K18/EP/012   8.96   9.07   2.73   0.82   1.60    3.8
#
#     Aggregate
# 16   9.552720
# 29   9.396047
# 4    9.395271
# 77   9.320233
# 76   9.278295
# ..        ...
# 52   4.969767
# 51   4.892248
# 47   4.711008
# 13   4.606047
# 33   4.586977
#
# [88 rows x 9 columns]

# %%
answer1.head(n=10)
# Out:
#                     Name     Roll No.  Sem-6  Sem-5  Sem-4  Sem-3  Sem-2  \
# 16            AMAN TYAGI  2K18/EP/010   9.83   9.44   9.64  10.00    9.0
# 29          SHIKHAR DASH  2K18/EP/080   9.35   9.32   9.45   9.55    9.5
# 4     PRIYANSH BHATNAGAR  2K18/EP/058   9.65   9.55   9.45   9.82    8.6
# 77         SHAURYA GUPTA  2K18/EP/078   9.83   9.55   9.82   9.64    8.1
# 76           TARUN ARORA  2K18/EP/085   9.52   9.27   9.27   9.73    9.0
# 78          VARUN MATHUR  2K18/EP/086   9.65   9.18   9.64   9.18    8.6
# 59  SAI SPANDANA THALLAM  2K18/EP/071   9.30   9.00   9.82   9.64    8.0
# 46           AKHIL GUPTA  2K18/EP/006   9.65   9.64   9.18   9.09    9.4
# 43           YASH MUDGAL  2K18/EP/093   9.48   9.18   9.27   9.27    7.5
# 30        SHOBHIT RANJAN  2K18/EP/081   9.17   9.22   9.45   9.18    9.0
#
#     Sem-1  Aggregate
# 16    9.3   9.552720
# 29    9.2   9.396047
# 4     9.2   9.395271
# 77    8.8   9.320233
# 76    8.8   9.278295
# 78    8.5   9.146899
# 59    8.7   9.100930
# 46    7.5   9.100543
# 43    8.7   8.929302
# 30    7.4   8.917840

# %% [markdown]
# # Take Aways  :
# ## the function is't modulated also optimization needs to be done since it is directly just reaading all the data at once which isn't good. What can we Do :
# 1. We know we are only taking data from Eningneering Physics so we can find the page where EP is written first as it is  provided at the start of each page and start extracting data from there.
# 2. We can make a common function to go throught the data as it will reduce the strain of writing same code again and again
# 3. The alogrithm has time complexity of O(n^2) which is definetly not feasible there is need to be work donw on that i.e. we can iterate at the page only when we find the EP page and etc.

# %%
#print(answer1)
# data.reset_index(inplace=True) another way to reset index starting from 0 
answer2 = answer1.set_index([pd.Index(range(88))]) # now we created a new dataframe which is sorted and indexed coorectly so plot will given the variation which is the expected one -_-
answer2.plot(y = 'Aggregate' , use_index = True) # plot without changing order of index correctly !!
# answer2.plot(y='Aggregate' , use_index = True , kind = 'scatter') # ** scatter doesn't work on indices 
answer2.keys()

# creating a csv file for the same : 
# import csv 
# with open('ranked data.csv','w') as file :
#     writer  = csv.DictWriter(file,fieldnames = answer2.keys())
#     writer.writeheader()
#     writer.writerows(answer)

#OR
# answer2.insert(0,"Rank",[i for i in range(1,89)],True)
# answer2.set_index('Rank', inplace=True)
# print(answer2)
# answer2.to_csv('ranked_data.csv')
# Out:
#                     Name     Roll No.  Sem-6  Sem-5  Sem-4  Sem-3  Sem-2  \
# Rank
# 1             AMAN TYAGI  2K18/EP/010   9.83   9.44   9.64  10.00   9.00
# 2           SHIKHAR DASH  2K18/EP/080   9.35   9.32   9.45   9.55   9.50
# 3     PRIYANSH BHATNAGAR  2K18/EP/058   9.65   9.55   9.45   9.82   8.60
# 4          SHAURYA GUPTA  2K18/EP/078   9.83   9.55   9.82   9.64   8.10
# 5            TARUN ARORA  2K18/EP/085   9.52   9.27   9.27   9.73   9.00
# ...                  ...          ...    ...    ...    ...    ...    ...
# 84          DIVYAM NIGAM  2K18/EP/024   8.48   5.82   5.73   3.18   1.90
# 85        ASHWAJIT SINGH  2K18/EP/018   8.96   8.73   5.57   3.11   0.70
# 86              AKSHANSH  2K18/EP/007   7.96   8.36   5.64   2.82   1.63
# 87    RUDRA PRATAP SINGH  2K18/EP/068   3.58   5.45   5.00   4.27   4.50
# 88             AMIT SETH  2K18/EP/012   8.96   9.07   2.73   0.82   1.60
#
#       Sem-1  Aggregate
# Rank
# 1       9.3   9.552720
# 2       9.2   9.396047
# 3       9.2   9.395271
# 4       8.8   9.320233
# 5       8.8   9.278295
# ...     ...        ...
# 84      4.2   4.969767
# 85      1.4   4.892248
# 86      1.1   4.711008
# 87      4.9   4.606047
# 88      3.8   4.586977
#
# [88 rows x 9 columns]

# %%
# plotting the mean variation in gpa of the batch : 
import matplotlib.pyplot as plt
answer['Sem-1'].mean() # caluclates mean of column 
aver = [answer['Sem-1'].mean(), answer['Sem-2'].mean(), answer['Sem-3'].mean(), answer["Sem-4"].mean(), answer['Sem-5'].mean(), answer['Sem-6'].mean()]
plt.plot([1,2,3,4,5,6],aver,'o',label = "Average gpa") # plot showing how cgpa varied with each semester number
plt.show()  
print(aver)
# Out:
# [6.467045454545457, 6.100568181818182, 6.673295454545452, 7.522386363636366, 8.777045454545457, 9.02715909090909]

# %%
def ranker():
    # performance curve for student depending on their roll number or rank : 
    x = input("Enter Name or Roll number(2K18/XX/0XX) : ")
    x = x.upper()
    answer2['Rank'] = range(1,89)
    answer2.set_index('Rank',inplace=True) # method to change index according to some other column
    data = None
    if x[0] == '2':
        data = answer2[answer2['Roll No.'] == x]
    else:
        data = answer2[answer2['Name'] == x]
    #rank = data.index.item() extracting index of this row to get it's rank  if we didn't use rank as index in answer2
    print(data)
    # plotting the data : 
    points = [data['Sem-1'],data['Sem-2'],data['Sem-3'],data['Sem-4'],data['Sem-5'],data['Sem-6']]
    data.reset_index(inplace = True)
    plt.plot([1,2,3,4,5,6],points)
    #print((points))
    plt.grid('on')
    plt.show()

# %%
ranker()
# Out:
# Enter Name or Roll number(2K18/XX/0XX) : Shaurya Gupta
#                Name     Roll No.  Sem-6  Sem-5  Sem-4  Sem-3  Sem-2  Sem-1  \
# Rank
# 4     SHAURYA GUPTA  2K18/EP/078   9.83   9.55   9.82   9.64    8.1    8.8
#
#       Aggregate
# Rank
# 4      9.320233
